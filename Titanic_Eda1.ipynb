# %% [markdown]
# # importing libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # import data

# %%
df = pd.read_csv('Titanic.csv')

# %% [markdown]
# # EDA ( Exploratory Data Analysis )

# %%
df.shape
# Out:
# (891, 12)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.columns.values
# Out:
# array(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
df.drop(columns=['Cabin'],inplace=True)

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df['Embarked'].fillna('S',inplace=True)

# %%
df['SibSp'].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
df['Parch'].value_counts()
# Out:
# Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %%
df['Survived'] = df['Survived'].astype('category')

# %%
df['Pclass'] = df['Pclass'].astype('category')

# %%
df['Sex'] = df['Sex'].astype('category')

# %%
df['Embarked'] = df['Embarked'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    category
#  2   Pclass       891 non-null    category
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    category
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    category
# dtypes: category(4), float64(2), int64(3), object(2)
# memory usage: 52.8+ KB

# %%
df.describe()
# Out:
#        PassengerId         Age       SibSp       Parch        Fare
# count   891.000000  714.000000  891.000000  891.000000  891.000000
# mean    446.000000   29.699118    0.523008    0.381594   32.204208
# std     257.353842   14.526497    1.102743    0.806057   49.693429
# min       1.000000    0.420000    0.000000    0.000000    0.000000
# 25%     223.500000   20.125000    0.000000    0.000000    7.910400
# 50%     446.000000   28.000000    0.000000    0.000000   14.454200
# 75%     668.500000   38.000000    1.000000    0.000000   31.000000
# max     891.000000   80.000000    8.000000    6.000000  512.329200

# %%
sns.set_style('whitegrid')
sns.countplot(x='Survived',data = df)
death_percent = round((df['Survived'].value_counts().values[0]/891)*100)
print("out of 891 {} percent people died in the accident".format(death_percent))
# Out:
# out of 891 62 percent people died in the accident

# %%
print((df['Pclass'].value_counts()/891)*100)
sns.countplot(x = 'Pclass',data = df)
# Out:
# Pclass
# 3    55.106622
# 1    24.242424
# 2    20.650954
# Name: count, dtype: float64
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
print((df['Sex'].value_counts()/891)*100)
sns.countplot(x = 'Sex', data = df)
# Out:
# Sex
# male      64.758698
# female    35.241302
# Name: count, dtype: float64
# <Axes: xlabel='Sex', ylabel='count'>

# %%
print(df['SibSp'].value_counts())
sns.countplot(x = 'SibSp', data = df)
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64
# <Axes: xlabel='SibSp', ylabel='count'>

# %%
print((df['Parch'].value_counts()/891)*100)
sns.countplot(x='Parch',data = df)
# Out:
# Parch
# 0    76.094276
# 1    13.243547
# 2     8.978676
# 5     0.561167
# 3     0.561167
# 4     0.448934
# 6     0.112233
# Name: count, dtype: float64
# <Axes: xlabel='Parch', ylabel='count'>

# %%
print((df['Embarked'].value_counts()/891)*100)
sns.countplot(x='Embarked',data = df)
# Out:
# Embarked
# S    72.502806
# C    18.855219
# Q     8.641975
# Name: count, dtype: float64
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
sns.distplot(df['Age'])
print(df['Age'].skew())
print(df['Age'].kurt())
# Out:
# C:\Users\deepa\AppData\Local\Temp\ipykernel_18348\350049838.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# 0.38910778230082704
# 0.17827415364210353

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
print("people with age in btw 60 and 70 :- ",df[(df['Age']>60) & (df['Age']<70)].shape[0])
print("people with age in btw 70 to 75  :- ",df[(df['Age']>70) & (df['Age']<75)].shape[0])
print("people with age greater than 75  :- ",df[(df['Age']>75)].shape[0])
print("people with age in btw 0 to 1    :- ",df[df['Age']<1].shape[0])
# Out:
# people with age in btw 60 and 70 :-  15
# people with age in btw 70 to 75  :-  4
# people with age greater than 75  :-  1
# people with age in btw 0 to 1    :-  7

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='Pclass',y='Age',data = df)
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
def input_age(cols):
    Age = cols[0]
    Pclass = cols[1]

    if pd.isnull(Age):
        if Pclass == 1:
            return 37
        elif Pclass == 2:
            return 29
        else:
            return 24
    else:
        return Age

# %%
df['Age'] = df[['Age','Pclass']].apply(input_age,axis=1)
# Out:
# C:\Users\deepa\AppData\Local\Temp\ipykernel_18348\2241368563.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Age = cols[0]
# C:\Users\deepa\AppData\Local\Temp\ipykernel_18348\2241368563.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Pclass = cols[1]

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
df['Fare'].hist(color='green',bins=30,figsize=(12,5))
# Out:
# <Axes: >

# %%
sns.distplot(df['Fare'])
print(df['Fare'].skew())
print(df['Fare'].kurt())
# Out:
# C:\Users\deepa\AppData\Local\Temp\ipykernel_18348\398100842.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Fare'])
# 4.787316519674893
# 33.39814088089868

# %%
sns.boxplot(df['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %%
print("people with Fare in btw 200 and 300 :- ",df[(df['Fare']>200) & (df['Fare']<300)].shape[0])
print("people with Fare is greater than 300  :- ",df[(df['Fare']>300)].shape[0])
# Out:
# people with Fare in btw 200 and 300 :-  17
# people with Fare is greater than 300  :-  3

# %% [markdown]
# # multi-varient analysis

# %%
sns.set_style('whitegrid')
sns.countplot(x='Survived',hue='Sex',data=df)
pd.crosstab(df['Sex'],df['Survived']).apply(lambda r: round((r/r.sum())*100,1), axis = 1)
# Out:
# Survived     0     1
# Sex
# female    25.8  74.2
# male      81.1  18.9

# %%
sns.set_style('whitegrid')
sns.countplot(x='Survived',hue='Pclass',data=df)
pd.crosstab(df['Pclass'],df['Survived']).apply(lambda r: round((r/r.sum())*100,1), axis = 1)
# Out:
# Survived     0     1
# Pclass
# 1         37.0  63.0
# 2         52.7  47.3
# 3         75.8  24.2

# %%
sns.set_style('whitegrid')
sns.countplot(x='Survived',hue='Sex',data=df)
pd.crosstab(df['Sex'],df['Survived']).apply(lambda r: round((r/r.sum())*100,1), axis = 1)
# Out:
# Survived     0     1
# Sex
# female    25.8  74.2
# male      81.1  18.9

# %%
# survived with embarked
sns.set_style('whitegrid')
sns.countplot(x='Survived',hue='Embarked',data=df)
pd.crosstab(df['Embarked'],df['Survived']).apply(lambda r: round((r/r.sum())*100,1), axis = 1)
# Out:
# Survived     0     1
# Embarked
# C         44.6  55.4
# Q         61.0  39.0
# S         66.1  33.9

# %%
# survived with age
plt.figure(figsize = (15,6))
sns.distplot(df[df['Survived'] == 0]['Age'])
sns.distplot(df[df['Survived'] == 1]['Age'])
# Out:
# C:\Users\deepa\AppData\Local\Temp\ipykernel_18348\1538434976.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['Survived'] == 0]['Age'])
# C:\Users\deepa\AppData\Local\Temp\ipykernel_18348\1538434976.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
plt.figure(figsize = (12,5))
sns.distplot(df[df['Survived'] == 0]['Fare'])
sns.distplot(df[df['Survived'] == 1]['Fare'])
# Out:
# C:\Users\deepa\AppData\Local\Temp\ipykernel_18348\2407218476.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['Survived'] == 0]['Fare'])
# C:\Users\deepa\AppData\Local\Temp\ipykernel_18348\2407218476.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sns.pairplot(df)

# %%
df_filtered = df.select_dtypes(include=[np.number])
sns.heatmap(df_filtered.corr())
# Out:
# <Axes: >

# %% [markdown]
# # feature engineering

# %%
df['family_size'] = df['Parch']+df['SibSp']

# %%
df.head()
# Out:
#    PassengerId Survived Pclass  \
# 0            1        0      3
# 1            2        1      1
# 2            3        1      3
# 3            4        1      1
# 4            5        0      3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked  family_size
# 0      0         A/5 21171   7.2500        S            1
# 1      0          PC 17599  71.2833        C            1
# 2      0  STON/O2. 3101282   7.9250        S            0
# 3      0            113803  53.1000        S            1
# ...

# %%
def family_type(number):
    if number == 0:
        return 'Alone'
    elif number>0 & number<=4:
        return 'Medium'
    else:
        return 'Large'

# %%
df['family_type'] = df['family_size'].apply(family_type)

# %%
df.drop(columns = ['SibSp','Parch','family_size'],inplace = True)

# %%
pd.crosstab(df['family_type'],df['Survived']).apply(lambda r : round((r/r.sum())*100,1), axis=1)
# Out:
# Survived        0     1
# family_type
# Alone        69.6  30.4
# Medium       49.4  50.6

# %%
# normal distrubution followed by age group
df=df[df['Age']<(df['Age'].mean() + 3 *df['Age'].std())]
df.shape
# Out:
# (884, 10)

# %%
# fare column is not follow normal distribution
Q1 = np.percentile(df['Fare'],25)
Q3 = np.percentile(df['Fare'],75)
outlier_low = Q1 - 1.5 *(Q3-Q1)
outlier_high = Q3 + 1.5* (Q3-Q1)
df = df[(df['Fare']>outlier_low) & (df['Fare']<outlier_high)]

# %%
df.sample(4)
# Out:
#      PassengerId Survived Pclass  \
# 206          207        0      3
# 18            19        0      3
# 813          814        0      3
# 407          408        1      2
#
#                                                   Name     Sex   Age   Ticket  \
# 206                         Backstrom, Mr. Karl Alfred    male  32.0  3101278
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0   345763
# 813                 Andersson, Miss. Ebba Iris Alfrida  female   6.0   347082
# 407                     Richards, Master. William Rowe    male   3.0    29106
#
#        Fare Embarked family_type
# 206  15.850        S      Medium
# 18   18.000        S      Medium
# 813  31.275        S      Medium
# 407  18.750        S      Medium

# %%
df = pd.get_dummies(data=df,columns=['Pclass','Sex','Embarked','family_type'],drop_first=True)

# %%
df
# Out:
#      PassengerId Survived                                          Name   Age  \
# 0              1        0                       Braund, Mr. Owen Harris  22.0
# 2              3        1                        Heikkinen, Miss. Laina  26.0
# 3              4        1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4              5        0                      Allen, Mr. William Henry  35.0
# 5              6        0                              Moran, Mr. James  24.0
# ..           ...      ...                                           ...   ...
# 886          887        0                         Montvila, Rev. Juozas  27.0
# 887          888        1                  Graham, Miss. Margaret Edith  19.0
# 888          889        0      Johnston, Miss. Catherine Helen "Carrie"  24.0
# 889          890        1                         Behr, Mr. Karl Howell  26.0
# 890          891        0                           Dooley, Mr. Patrick  32.0
#
# ...
